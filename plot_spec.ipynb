# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
plt.style.use('science')
colors = {
    'red': '#E24A33',
    'blue': '#348ABD',
    'green': '#8EBA42',
    'orange': '#FBC15E',
    'purple': '#988ED5',
    'pink': '#FFB5B8',
    'gray': '#777777'
}
plt.rcParams.update({
    'font.size': 12,               # 字体大小
    'font.family': 'sans-serif',    # 字体类型
    'font.sans-serif': ['Arial'],   # 使用 Arial 字体
    'axes.linewidth': 1.5,          # 坐标轴线宽
    'axes.labelsize': 14,           # 坐标轴标签大小
    'axes.titlesize': 14,           # 标题字体大小
    'xtick.labelsize': 12,          # X轴刻度字体大小
    'ytick.labelsize': 12,          # Y轴刻度字体大小
    'xtick.major.size': 5,          # X轴主刻度长度
    'ytick.major.size': 5,          # Y轴主刻度长度
    'xtick.major.width': 1.5,       # X轴主刻度宽度
    'ytick.major.width': 1.5,       # Y轴主刻度宽度
    'legend.fontsize': 12,          # 图例字体大小
    'legend.frameon': False,        # 图例无边框
    'lines.linewidth': 1.5,         # 曲线的默认线宽
    'savefig.dpi': 300,             # 保存图片的分辨率
    'figure.figsize': (5, 5),       # 图形大小 (以英寸为单位)
    'figure.autolayout': False       # 自动调整布局
})

# %%
#read txt files
df0 = pd.read_csv('/Volumes/WD_BLACK/Data/1A0535p262/HXMT/date_combine/20201120/avg.qdp',sep=' ')
df01 = pd.read_csv('/Volumes/WD_BLACK/Data/1A0535p262/HXMT/date_combine/20201208/avg.qdp',sep=' ')
df02 = pd.read_csv('/Volumes/WD_BLACK/Data/1A0535p262/HXMT/date_combine/20201213/avg.qdp',sep=' ')

df1 = pd.read_csv('20201120_QPOphase/0001.qdp', sep=' ') 
df11 = pd.read_csv('20201208_QPOphase/0001.qdp', sep=' ') 
df12 = pd.read_csv('20201213_QPOphase/0001.qdp', sep=' ') 

df2 = pd.read_csv('20201120_QPOphase/0506.qdp', sep=' ') 
df21 = pd.read_csv('20201208_QPOphase/0506.qdp', sep=' ') 
df22 = pd.read_csv('20201213_QPOphase/0506.qdp', sep=' ') 

df3 = pd.read_csv('20201120_QPOphase/0001_del.qdp', sep=' ') 
df31 = pd.read_csv('20201208_QPOphase/0001_del.qdp', sep=' ') 
df32 = pd.read_csv('20201213_QPOphase/0001_del.qdp', sep=' ') 

df4 = pd.read_csv('20201120_QPOphase/0506_del.qdp', sep=' ') 
df41 = pd.read_csv('20201208_QPOphase/0506_del.qdp', sep=' ') 
df42 = pd.read_csv('20201213_QPOphase/0506_del.qdp', sep=' ')

# %%
#for Average Spectru
#read energies
x0,x01,x02=np.array(df0['E']),np.array(df01['E']),np.array(df02['E'])
x0_err,x01_err, x02_err=np.array(df0['E_err']),np.array(df01['E_err']),np.array(df02['E_err'])
#read spectra
y0,y01,y02=np.array(df0['Flux']),np.array(df01['Flux']),np.array(df02['Flux'])
y0_err,y01_err,y02_err=np.array(df0['Flux_err']),np.array(df01['Flux_err']),np.array(df02['Flux_err'])
#read models
y0_add1,y01_add1,y02_add1=np.array(df0['Add1']),np.array(df01['Add1']),np.array(df02['Add1'])
y0_add2,y01_add2,y02_add2=np.array(df0['Add2']),np.array(df01['Add2']),np.array(df02['Add2'])

#for 0001 Spectru
#read energies
x1,x11,x12=np.array(df1['E']),np.array(df11['E']),np.array(df12['E'])
x1_err,x11_err, x12_err=np.array(df1['E_err']),np.array(df11['E_err']),np.array(df12['E_err'])
#read spectra
y1,y11,y12=np.array(df1['Flux']),np.array(df11['Flux']),np.array(df12['Flux'])
y1_err,y11_err,y12_err=np.array(df1['Flux_err']),np.array(df11['Flux_err']),np.array(df12['Flux_err'])
#read models
y1_add1,y11_add1,y12_add1=np.array(df1['Add1']),np.array(df11['Add1']),np.array(df12['Add1'])
y1_add2,y11_add2,y12_add2=np.array(df1['Add2']),np.array(df11['Add2']),np.array(df12['Add2'])

#for 0506 Spectru
#read energies
x2,x21,x22=np.array(df2['E']),np.array(df21['E']),np.array(df22['E'])
x2_err,x21_err,x22_err=np.array(df2['E_err']),np.array(df21['E_err']),np.array(df22['E_err'])
#read spectra
y2,y21,y22=np.array(df2['Flux']),np.array(df21['Flux']),np.array(df22['Flux'])
y2_err,y21_err,y22_err=np.array(df2['Flux_err']),np.array(df21['Flux_err']),np.array(df22['Flux_err'])
#read models
y2_add1,y21_add1,y22_add1=np.array(df2['Add1']),np.array(df21['Add1']),np.array(df22['Add1'])
y2_add2,y21_add2,y22_add2=np.array(df2['Add2']),np.array(df21['Add2']),np.array(df22['Add2'])

#for 0001 residuals
x3,x31,x32=np.array(df3['E']),np.array(df31['E']),np.array(df32['E'])
x3_err,x31_err, x32_err=np.array(df3['E_err']),np.array(df31['E_err']),np.array(df32['E_err'])
y3,y31,y32=np.array(df3['Delta']),np.array(df31['Delta']),np.array(df32['Delta'])
y3_err,y31_err,y32_err=np.array(df3['Delta_err']),np.array(df31['Delta_err']),np.array(df32['Delta_err'])

#for 0506 residuals
x4,x41,x42=np.array(df4['E']),np.array(df41['E']),np.array(df42['E'])
x4_err,x41_err, x42_err=np.array(df4['E_err']),np.array(df41['E_err']),np.array(df42['E_err'])
y4,y41,y42=np.array(df4['Delta']),np.array(df41['Delta']),np.array(df42['Delta'])
y4_err,y41_err,y42_err=np.array(df4['Delta_err']),np.array(df41['Delta_err']),np.array(df42['Delta_err'])

# %% [raw]
# fig, axs = plt.subplots(2,3,figsize=(18, 6), gridspec_kw={'height_ratios': [3, 1]})
#
# #plot spectrum on 2020-11-20
# # axs[0][0].errorbar(x0,y0,xerr=x0_err,yerr=y0_err,drawstyle='steps-mid',color='r',ecolor='r',
# #                    label=r'avg: Lum=$10.9\times10^{37}$',lw=1)
# axs[0][0].errorbar(x1,y1,xerr=x1_err,yerr=y1_err,fmt='.',color=colors['red'],ecolor=colors['red'],
#                    label=r'$L_{\rm 0.0-0.1}=10.3\times10^{37}$ erg/s',alpha=0.4,lw=2)
# axs[0][0].errorbar(x2,y2,xerr=x2_err,yerr=y2_err,fmt='.',color=colors['blue'],ecolor=colors['blue'],
#                    label=r'$L_{\rm 0.5-0.6}=11.9\times10^{37}$ erg/s',alpha=0.4,lw=2)
# axs[0][0].plot(x1,y1_add1,'--',color='black',lw=3)
# axs[0][0].plot(x1,y1_add2,'--',color='black',lw=3)
# axs[0][0].plot(x2,y2_add1,'--',color='black',lw=3)
# axs[0][0].plot(x2,y2_add2,'--',color='black',lw=3)
# #Ecyc=43.1
# #axs[0][0].axvline(x=Ecyc, color='r', linestyle='--',label=r"$E_{\rm cyc}=43.1$ keV")
# axs[0][0].axvspan(39.5, 47.1, facecolor=colors['green'], alpha=0.7)
#
# #plot spectrum on 2020-12-08
# # axs[1][0].errorbar(x01,y01,xerr=x01_err,yerr=y01_err,drawstyle='steps-mid',color='r',ecolor='r',
# #                    label=r'avg: Lum=$10.9\times10^{37}$',lw=1)
# axs[0][1].errorbar(x11,y11,xerr=x11_err,yerr=y11_err,fmt='.',color=colors['red'],ecolor=colors['red'],
#                    label=r'$L_{\rm 0.0-0.1}=3.9\times10^{37}$ erg/s',alpha=0.4,lw=2)
# axs[0][1].errorbar(x21,y21,xerr=x21_err,yerr=y21_err,fmt='.',color=colors['blue'],ecolor=colors['blue'],
#                    label=r'$L_{\rm 0.5-0.6}=4.7\times10^{37}$ erg/s',alpha=0.4,lw=2)
# axs[0][1].plot(x11,y11_add1,'--',color='black',lw=3)
# axs[0][1].plot(x11,y11_add2,'--',color='black',lw=3)
# axs[0][1].plot(x21,y21_add1,'--',color='black',lw=3)
# axs[0][1].plot(x21,y21_add2,'--',color='black',lw=3)
# #Ecyc=47.2
# #axs[0][1].axvline(x=Ecyc, color='r', linestyle='--',label=r"$E_{\rm cyc}=47.2$ keV")
# axs[0][1].axvspan(45.9, 49.5, facecolor=colors['green'], alpha=0.7)
# #axs[1][0].legend()
#
# #plot spectrum on 2020-12-13
# # axs[2][0].errorbar(x02,y02,xerr=x02_err,yerr=y02_err,drawstyle='steps-mid',color='r',ecolor='r',
# #                    label=r'avg: Lum=$10.9\times10^{37}$',lw=1)
# axs[0][2].errorbar(x12,y12,xerr=x12_err,yerr=y12_err,fmt='.',color=colors['red'],ecolor=colors['red'],
#                    label=r'$L_{\rm 0.0-0.1}=2.3\times10^{37}$ erg/s',alpha=0.4,lw=2)
# axs[0][2].errorbar(x22,y22,xerr=x22_err,yerr=y22_err,fmt='.',color=colors['blue'],ecolor=colors['blue'],
#                    label=r'$L_{\rm 0.5-0.6}=2.8\times10^{37}$ erg/s',alpha=0.4,lw=2)
# axs[0][2].plot(x12,y12_add1,'--',color='black',lw=3)
# axs[0][2].plot(x12,y12_add2,'--',color='black',lw=3)
# axs[0][2].plot(x22,y22_add1,'--',color='black',lw=3)
# axs[0][2].plot(x22,y22_add2,'--',color='black',lw=3)
# #Ecyc=47.2
# #axs[0][2].axvline(x=Ecyc, color='r', linestyle='--',label=r"$E_{\rm cyc}=47.2$ keV")
# axs[0][2].axvspan(44.7, 49.3, facecolor=colors['green'], alpha=0.7)
# #axs[1][0].legend()
#
# #plot residuals on 2020-11-20
# axs[1][0].errorbar(x3,y3,xerr=x3_err,yerr=y3_err,fmt='.',color=colors['red'],ecolor=colors['red'],lw=2,alpha=0.4)
# axs[1][0].errorbar(x4,y4,xerr=x4_err,yerr=y4_err,fmt='.',color=colors['blue'],ecolor=colors['blue'],lw=2,alpha=0.4)
# axs[1][0].axhline(y=0, color='black', linestyle='--',lw=3)
# axs[1][0].set_ylim(-4.8,4.8)
# #plot residuals on 2020-12-08
# axs[1][1].errorbar(x31,y31,xerr=x31_err,yerr=y31_err,fmt='.',color=colors['red'],ecolor=colors['red'],lw=2,alpha=0.4)
# axs[1][1].errorbar(x41,y41,xerr=x41_err,yerr=y41_err,fmt='.',color=colors['blue'],ecolor=colors['blue'],lw=2,alpha=0.4)
# axs[1][1].axhline(y=0, color='black', linestyle='--',lw=3)
# axs[1][1].set_ylim(-4.8,4.8)
# #plot residuals on 2020-12-13
# axs[1][2].errorbar(x32,y32,xerr=x32_err,yerr=y32_err,fmt='.',color=colors['red'],ecolor=colors['red'],lw=2,alpha=0.4)
# axs[1][2].errorbar(x42,y42,xerr=x42_err,yerr=y42_err,fmt='.',color=colors['blue'],ecolor=colors['blue'],lw=2,alpha=0.4)
# axs[1][2].axhline(y=0, color='black', linestyle='--',lw=3)
# axs[1][2].set_ylim(-4.8,4.8)
#
#
# axs[0][0].legend(loc='upper left',frameon=False)
# axs[0][1].legend(loc='upper left',frameon=False)
# axs[0][2].legend(loc='upper left',frameon=False)
# #axs[0][2].legend.get_frame().set_linewidth(0)  # 去掉图例边框
# axs[0][0].set_yscale('log')
# axs[0][0].set_xscale('log')
# axs[0][0].set_ylim(1.1e-1,5e2)
# axs[0][1].set_yscale('log')
# axs[0][1].set_xscale('log')
# axs[0][1].set_ylim(1.1e-1,5e2)
# axs[0][2].set_yscale('log')
# axs[0][2].set_xscale('log')
# axs[0][2].set_ylim(1.1e-1,5e2)
# axs[1][0].set_xscale('log')
# axs[1][1].set_xscale('log')
# axs[1][2].set_xscale('log')
# #文本标注
# axs[0][0].set_title('Date: 2020-11-20', fontsize=14, fontweight='bold',fontname='Times New Roman')
# axs[0][1].set_title('Date: 2020-12-08', fontsize=14, fontweight='bold',fontname='Times New Roman')
# axs[0][2].set_title('Date: 2020-12-13', fontsize=14, fontweight='bold',fontname='Times New Roman')
# #设置y轴单位
# axs[0][0].set_ylabel(r'keV$^2$ (Photons cm$^{-2}$ s$^{-1}$ keV$^{-1}$)'
#                      ,fontsize=14, fontweight='bold',fontname='Times New Roman')
# axs[0][1].set_ylabel(r'keV$^2$ (Photons cm$^{-2}$ s$^{-1}$ keV$^{-1}$)'
#                      ,fontsize=14, fontweight='bold',fontname='Times New Roman')
# axs[0][2].set_ylabel(r'keV$^2$ (Photons cm$^{-2}$ s$^{-1}$ keV$^{-1}$)'
#                      ,fontsize=14, fontweight='bold',fontname='Times New Roman')
# axs[1][0].set_ylabel(r'$\Delta\ \chi^2$',fontsize=14, fontweight='bold',fontname='Times New Roman')
# axs[1][1].set_ylabel(r'$\Delta\ \chi^2$',fontsize=14, fontweight='bold',fontname='Times New Roman')
# axs[1][2].set_ylabel(r'$\Delta\ \chi^2$',fontsize=14, fontweight='bold',fontname='Times New Roman')
# axs[1][0].set_xlabel('Energy (keV)',fontsize=14, fontweight='bold',fontname='Times New Roman')
# axs[1][1].set_xlabel('Energy (keV)',fontsize=14, fontweight='bold',fontname='Times New Roman')
# axs[1][2].set_xlabel('Energy (keV)',fontsize=14, fontweight='bold',fontname='Times New Roman')
#
# #================================================
# # 设置边框的粗细
# for spine in ['top', 'right', 'bottom', 'left']:
#     axs[0][0].spines[spine].set_linewidth(2)
# for spine in ['top', 'right', 'bottom', 'left']:
#     axs[0][1].spines[spine].set_linewidth(2)
# for spine in ['top', 'right', 'bottom', 'left']:
#     axs[0][2].spines[spine].set_linewidth(2)
# for spine in ['top', 'right', 'bottom', 'left']:
#     axs[1][0].spines[spine].set_linewidth(2)
# for spine in ['top', 'right', 'bottom', 'left']:
#     axs[1][1].spines[spine].set_linewidth(2)
# for spine in ['top', 'right', 'bottom', 'left']:
#     axs[1][2].spines[spine].set_linewidth(2)
# # ax.tick_params(axis='x', which='both', bottom=False, top=True, labelbottom=False, labeltop=True)
# axs[0,0].tick_params(axis='x', which='both',color='black',direction='in')
# axs[0,1].tick_params(axis='x', which='both',color='black',direction='in')
# axs[0,2].tick_params(axis='x', which='both',color='black',direction='in')
# axs[1,0].tick_params(axis='x', which='both',color='black',direction='in')
# axs[1,1].tick_params(axis='x', which='both',color='black',direction='in')
# axs[1,2].tick_params(axis='x', which='both',color='black',direction='in')
# axs[0,0].tick_params(axis='both', which='major', length=7, width=2, color='black')
# axs[0,1].tick_params(axis='both', which='major', length=7, width=2, color='black')
# axs[0,2].tick_params(axis='both', which='major', length=7, width=2, color='black')
# axs[1,0].tick_params(axis='x', which='major', length=7, width=2, color='black')
# axs[1,1].tick_params(axis='x', which='major', length=7, width=2, color='black')
# axs[1,2].tick_params(axis='x', which='major', length=7, width=2, color='black')
# #=================================================
# plt.subplots_adjust(hspace=0)
# #plt.savefig("/Users/kldsky/Desktop/1A0535_results/fdcut/spectra_fit.pdf")
# plt.show()

# %%
fig, axs = plt.subplots(2,1, gridspec_kw={'height_ratios': [3, 1]})
#axs = plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios': [3, 1]})
# fig, axs = plt.subplots(2,1,figsize=(5, 5))

#plot spectrum on 2020-11-20
# axs[0][0].errorbar(x0,y0,xerr=x0_err,yerr=y0_err,drawstyle='steps-mid',color='r',ecolor='r',
#                    label=r'avg: Lum=$10.9\times10^{37}$',lw=1)
axs[0].errorbar(x1,y1,xerr=x1_err,yerr=y1_err,fmt='.',color=colors['red'],ecolor=colors['red'],
                   label=r'$L_{\rm 0.0-0.1}=10.3\times10^{37}$ erg/s',alpha=0.4,lw=2)
axs[0].errorbar(x2,y2,xerr=x2_err,yerr=y2_err,fmt='.',color=colors['blue'],ecolor=colors['blue'],
                   label=r'$L_{\rm 0.5-0.6}=11.9\times10^{37}$ erg/s',alpha=0.4,lw=2)
axs[0].plot(x1,y1_add1,'--',color='black',lw=3)
axs[0].plot(x1,y1_add2,'--',color='black',lw=3)
axs[0].plot(x2,y2_add1,'--',color='black',lw=3)
axs[0].plot(x2,y2_add2,'--',color='black',lw=3)
#Ecyc=43.1
#axs[0][0].axvline(x=Ecyc, color='r', linestyle='--',label=r"$E_{\rm cyc}=43.1$ keV")
axs[0].axvspan(39.5, 47.1, facecolor=colors['green'], alpha=0.7)

#plot residuals on 2020-11-20
axs[1].errorbar(x3,y3,xerr=x3_err,yerr=y3_err,fmt='.',color=colors['red'],ecolor=colors['red'],lw=2,alpha=0.4)
axs[1].errorbar(x4,y4,xerr=x4_err,yerr=y4_err,fmt='.',color=colors['blue'],ecolor=colors['blue'],lw=2,alpha=0.4)
axs[1].axhline(y=0, color='black', linestyle='--',lw=3)
axs[1].set_ylim(-4.8,4.8)

axs[0].legend(loc='upper left',frameon=False,fontsize=9)
axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_ylim(1.1e-1,5e2)
axs[1].set_xscale('log')

#文本标注
axs[0].set_title('Date: 2020-11-20',fontsize=12) 
#设置y轴单位
axs[0].set_ylabel(r'keV$^2$ (Photons cm$^{-2}$ s$^{-1}$ keV$^{-1}$)',fontsize=12)
axs[1].set_ylabel(r'$\Delta\ \chi^2$',fontsize=12)
axs[1].set_xlabel('Energy (keV)',fontsize=12)
plt.subplots_adjust(hspace=0)
plt.savefig("spectra_fit_20201120.pdf")
# plt.show()

# %%
fig, axs = plt.subplots(2,1,figsize=(5, 5), gridspec_kw={'height_ratios': [3, 1]})

#plot spectrum on 2020-12-08
# axs[1][0].errorbar(x01,y01,xerr=x01_err,yerr=y01_err,drawstyle='steps-mid',color='r',ecolor='r',
#                    label=r'avg: Lum=$10.9\times10^{37}$',lw=1)
axs[0].errorbar(x11,y11,xerr=x11_err,yerr=y11_err,fmt='.',color=colors['red'],ecolor=colors['red'],
                   label=r'$L_{\rm 0.0-0.1}=3.9\times10^{37}$ erg/s',alpha=0.4,lw=2)
axs[0].errorbar(x21,y21,xerr=x21_err,yerr=y21_err,fmt='.',color=colors['blue'],ecolor=colors['blue'],
                   label=r'$L_{\rm 0.5-0.6}=4.7\times10^{37}$ erg/s',alpha=0.4,lw=2)
axs[0].plot(x11,y11_add1,'--',color='black',lw=3)
axs[0].plot(x11,y11_add2,'--',color='black',lw=3)
axs[0].plot(x21,y21_add1,'--',color='black',lw=3)
axs[0].plot(x21,y21_add2,'--',color='black',lw=3)
#Ecyc=47.2
#axs[0].axvline(x=Ecyc, color='r', linestyle='--',label=r"$E_{\rm cyc}=47.2$ keV")
axs[0].axvspan(45.9, 49.5, facecolor=colors['green'], alpha=0.7)

#plot residuals on 2020-12-08
axs[1].errorbar(x31,y31,xerr=x31_err,yerr=y31_err,fmt='.',color=colors['red'],ecolor=colors['red'],lw=2,alpha=0.4)
axs[1].errorbar(x41,y41,xerr=x41_err,yerr=y41_err,fmt='.',color=colors['blue'],ecolor=colors['blue'],lw=2,alpha=0.4)
axs[1].axhline(y=0, color='black', linestyle='--',lw=3)
axs[1].set_ylim(-4.8,4.8)

axs[0].legend(loc='upper left',frameon=False,fontsize=9)
#axs[0][2].legend.get_frame().set_linewidth(0)  # 去掉图例边框
axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_ylim(1.1e-1,5e2)
axs[1].set_xscale('log')

#文本标注
axs[0].set_title('Date: 2020-12-08') 
#设置y轴单位
axs[0].set_ylabel(r'keV$^2$ (Photons cm$^{-2}$ s$^{-1}$ keV$^{-1}$)')
axs[1].set_ylabel(r'$\Delta\ \chi^2$')
axs[1].set_xlabel('Energy (keV)')

plt.subplots_adjust(hspace=0)
plt.savefig("spectra_fit_20201208.pdf")
# plt.show()

# %%
fig, axs = plt.subplots(2,1,figsize=(5, 5), gridspec_kw={'height_ratios': [3, 1]})

#plot spectrum on 2020-12-13
axs[0].errorbar(x12,y12,xerr=x12_err,yerr=y12_err,fmt='.',color=colors['red'],ecolor=colors['red'],
                   label=r'$L_{\rm 0.0-0.1}=2.3\times10^{37}$ erg/s',alpha=0.4,lw=2)
axs[0].errorbar(x22,y22,xerr=x22_err,yerr=y22_err,fmt='.',color=colors['blue'],ecolor=colors['blue'],
                   label=r'$L_{\rm 0.5-0.6}=2.8\times10^{37}$ erg/s',alpha=0.4,lw=2)
axs[0].plot(x12,y12_add1,'--',color='black',lw=3)
axs[0].plot(x12,y12_add2,'--',color='black',lw=3)
axs[0].plot(x22,y22_add1,'--',color='black',lw=3)
axs[0].plot(x22,y22_add2,'--',color='black',lw=3)
#Ecyc=47.2
#axs[0].axvline(x=Ecyc, color='r', linestyle='--',label=r"$E_{\rm cyc}=47.2$ keV")
axs[0].axvspan(44.7, 49.3, facecolor=colors['green'], alpha=0.7)
#axs[1].legend()

#plot residuals on 2020-12-13
axs[1].errorbar(x32,y32,xerr=x32_err,yerr=y32_err,fmt='.',color=colors['red'],ecolor=colors['red'],lw=2,alpha=0.4)
axs[1].errorbar(x42,y42,xerr=x42_err,yerr=y42_err,fmt='.',color=colors['blue'],ecolor=colors['blue'],lw=2,alpha=0.4)
axs[1].axhline(y=0, color='black', linestyle='--',lw=3)
axs[1].set_ylim(-4.8,4.8)

axs[0].legend(loc='upper left',frameon=False,fontsize=9)
#axs[0][2].legend.get_frame().set_linewidth(0)  # 去掉图例边框
axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_ylim(1.1e-1,5e2)
axs[1].set_xscale('log')

#文本标注
axs[0].set_title('Date: 2020-12-13') 
#设置y轴单位
axs[0].set_ylabel(r'keV$^2$ (Photons cm$^{-2}$ s$^{-1}$ keV$^{-1}$)')
axs[1].set_ylabel(r'$\Delta\ \chi^2$')
axs[1].set_xlabel('Energy (keV)')

plt.subplots_adjust(hspace=0)
plt.savefig("spectra_fit_20201213.pdf")
# plt.show()
